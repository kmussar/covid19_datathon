# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import re
import folium as folium

# %%
df_raw = pd.read_csv('/content/drive/My Drive/mit-covid-hackathon/data-and-notebooks/raceDataTrackerDeaths.csv', 
                 names = ['Date', 'State', 'Update Time', 'Source', 'Update Time (Et)',
       'Last Check', 'Checker', 'DC', 'Total', 'White ', 'Black ',
       'LatinX_Hispanic', 'Asian', 'AIAN', 'NHPI',
       'Multiracial', 'Other', 'Unknown',
       'Race_Percent_Unknown', 'Ethnicity_Hispanic', 'Ethnicity_Non-Hispanic',
       'Ethnicity_Unknown', 'Ethnicity_Percent_Unknown', 'Notes'], low_memory=False) 
df_raw.columns
# Out:
# Index(['Date', 'State', 'Update Time', 'Source', 'Update Time (Et)',
#        'Last Check', 'Checker', 'DC', 'Total', 'White ', 'Black ',
#        'LatinX_Hispanic', 'Asian', 'AIAN', 'NHPI', 'Multiracial', 'Other',
#        'Unknown', 'Race_Percent_Unknown', 'Ethnicity_Hispanic',
#        'Ethnicity_Non-Hispanic', 'Ethnicity_Unknown',
#        'Ethnicity_Percent_Unknown', 'Notes'],
#       dtype='object')

# %%
df_raw.head
# Out:
# <bound method NDFrame.head of          Date  State  ...  Ethnicity_Percent_Unknown  Notes
# 0        Date  State  ...  Ethnicity_Percent_Unknown  Notes
# 1    20200510     AK  ...                        100    NaN
# 2    20200510     AL  ...                         11    NaN
# 3    20200510     AR  ...                        100    NaN
# 4    20200510     AS  ...                        100    NaN
# ..        ...    ...  ...                        ...    ...
# 500  20200412     VT  ...                        NaN    NaN
# 501  20200412     WA  ...                         26    NaN
# 502  20200412     WI  ...                          1    NaN
# 503  20200412     WV  ...                        NaN    NaN
# 504  20200412     WY  ...                        NaN    NaN
#
# [505 rows x 24 columns]>

# %%
# Drop media columns 
df_raw.drop(['Update Time', 'Source', 'Update Time (Et)',
       'Last Check', 'Checker', 'DC','Notes'], axis=1, inplace=True)
df_raw.columns
# Out:
# Index(['Date', 'State', 'Total', 'White ', 'Black ', 'LatinX_Hispanic',
#        'Asian', 'AIAN', 'NHPI', 'Multiracial', 'Other', 'Unknown',
#        'Race_Percent_Unknown', 'Ethnicity_Hispanic', 'Ethnicity_Non-Hispanic',
#        'Ethnicity_Unknown', 'Ethnicity_Percent_Unknown'],
#       dtype='object')

# %%
df_raw.describe()
# Out:
#             Date State  ... Ethnicity_Unknown Ethnicity_Percent_Unknown
# count        505   505  ...               214                       224
# unique        10    57  ...               136                        57
# top     20200503    SD  ...                 0                         0
# freq          56     9  ...                 9                        20
#
# [4 rows x 17 columns]

# %%
# display only the number of rows of the ‘df’ DataFrame
df_raw.shape[0]
# Out:
# 505

# %%
# df with just most recent date, as info is cumulative
df = df_raw[df_raw.Date == '20200510']

# %%
# display only the number of rows of the ‘df’ DataFrame
df.shape[0]
# Out:
# 56

# %%
# count the number of unique values
df.State.nunique()
# Out:
# 56

# %% [markdown]
# 56 because this data includes 6 of 9 additional US commonwealth & terrirories: 'AS' =   'DC',  'GU',  'MP', 'PR', 'VI'
# * American Samoa - AS
# * District of Columbia - DC
# * Federated States of Micronesia - FM
# * Guam - GU
# * Marshall Islands - MH
# * Northern Mariana Islands - MP
# * Palau - PW
# * Puerto Rico - PR
# * Virgin Islands - VI

# %%
# return the unique values
df.State.unique()
# Out:
# array(['AK', 'AL', 'AR', 'AS', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL',
#        'GA', 'GU', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA',
#        'MD', 'ME', 'MI', 'MN', 'MO', 'MP', 'MS', 'MT', 'NC', 'ND', 'NE',
#        'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI',
#        'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VI', 'VT', 'WA', 'WI', 'WV',
#        'WY'], dtype=object)

# %%
# lowercase column names by mapping the lowering function to all column names
df.columns = map(str.lower, df.columns)
df.head()
# Out:
#        date state  ... ethnicity_unknown ethnicity_percent_unknown
# 1  20200510    AK  ...                10                       100
# 2  20200510    AL  ...                42                        11
# 3  20200510    AR  ...                82                       100
# 4  20200510    AS  ...               NaN                       100
# 5  20200510    AZ  ...                95                        18
#
# [5 rows x 17 columns]

# %%
df.describe()
# Out:
#             date state  ... ethnicity_unknown ethnicity_percent_unknown
# count         56    56  ...                38                        39
# unique         1    56  ...                33                        25
# top     20200510    TN  ...                 2                       100
# freq          56     1  ...                 2                         4
#
# [4 rows x 17 columns]

# %%
# count number of non NA values for race_percent_unknown
df['race_percent_unknown'].count()
# Missing race data for 1 state ()
# Out:
# 55

# %%
# count number of non NA values for ethnicity_percent_unknown
df['ethnicity_percent_unknown'].count()
# Missing ethnicity data for 7 states/territories
# Out:
# 39

# %%
# Drop ethnicity columns as group is focusing analysis on race
df.drop(['date', 'ethnicity_hispanic',	'ethnicity_non-hispanic', 'ethnicity_unknown', 'ethnicity_percent_unknown'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.columns
# Out:
# Index(['state', 'total', 'white ', 'black ', 'latinx_hispanic', 'asian',
#        'aian', 'nhpi', 'multiracial', 'other', 'unknown',
#        'race_percent_unknown'],
#       dtype='object')

# %%
df.describe()
# Out:
#        state total white  black   ... multiracial other unknown race_percent_unknown
# count     56    55     41     39  ...          10    36      54                   55
# unique    56    54     41     38  ...           9    25      46                   25
# top       TN    67    211      1  ...          10     2       0                  100
# freq       1     2      1      2  ...           2     4       5                   14
#
# [4 rows x 12 columns]

# %%
# For how many states/regions are we missing data for one or more races?
df.isna().sum()
# Out:
# state                    0
# total                    1
# white                   15
# black                   17
# latinx_hispanic         38
# asian                   23
# aian                    40
# nhpi                    45
# multiracial             46
# other                   20
# unknown                  2
# race_percent_unknown     1
# dtype: int64

# %% [markdown]
# These races have particularly high amounts of missing data
# *   multiracial             46 (missing data 82% of the time)
# *   nhpi                    45 (missing data 80% of the time)
# *   aian                    40 (missing data 71% of the time)
# *   latinx_hispanic         38 (missing data 68% of the time)
# *   asian                   23 (missing data 41% of the time)
# *   black                   17 (missing data 30% of the time)

# %%
pd.value_counts(df['race_percent_unknown'].values, sort=True)
# Out:
# 100    14
# 0       5
# 3       4
# 5       3
# 4       3
# 2       2
# 1       2
# 13      2
# 7       2
# 10      2
# 20      2
# 9       1
# 8       1
# 19      1
# 11      1
# 46      1
# 66      1
# 35      1
# 12      1
# 23      1
# 52      1
# 56      1
# 6       1
# 18      1
# 94      1
# dtype: int64

# %%
df.sort_values('race_percent_unknown', ascending=False, inplace=True)
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    state  total white  black   ... multiracial other unknown race_percent_unknown
# 55    WV     50      2      1  ...         NaN   NaN      47                   94
# 53    WA    931    622     28  ...          10    19      86                    9
# 10    DE    224    132     58  ...         NaN     3      17                    8
# 21    LA   2213    833   1184  ...         NaN    16     157                    7
# 7     CO    971    619     63  ...          10     6      63                    7
# 48    TX   1088    176     66  ...         NaN     1     722                   66
# 23    MD   1538    637    631  ...         NaN    22      88                    6
# 34    NH    133     54      0  ...         NaN     1      74                   56
# 42    PA   3707   1357    388  ...         NaN    11    1911                   52
# 31    NC    547    312    177  ...         NaN    20      30                    5
# 39    OH   1341   1017    218  ...          15    10      71                    5
# 25    MI   4570   2229   1865  ...          91    91     227                    5
# 22    MA   4979   1911    253  ...         NaN   154    2280                   46
# 11    FL   1721    859    363  ...         NaN    60      76                    4
# 3     AR     82     45     30  ...         NaN     4       3                    4
# 40    OK    272    206     22  ...         NaN     7      12                    4
# 38    NY  21478   5423   3409  ...         NaN   575    7485                   35
# 16    ID     67     62      1  ...         NaN   NaN       2                    3
# 8     CT   2967   2127    439  ...         NaN    14      89                    3
# 47    TN    243    146     76  ...         NaN     7       8                    3
# 6     CA   2657    891    264  ...          14    36      89                    3
# 26    MN    578    387     34  ...           5     2     132                   23
# 41    OR    109     81      5  ...           1     6      25                   20
# 44    RI    422    269     20  ...           0     6      83                   20
# 2     AL    393    194    178  ...         NaN     5       9                    2
# 12    GA   1405    602    693  ...         NaN     9      22                    2
# 27    MO    482    197    159  ...           9    24      91                   19
# 5     AZ    536    240     17  ...         NaN     7      95                   18
# 45    SC    331    161    122  ...         NaN     3      42                   13
# 50    VA    839    451    187  ...         NaN    92     109                   13
# 20    KY    304    211     50  ...           2   NaN      36                   12
# 35    NJ   9255   4354   1578  ...         NaN   438     993                   11
# 46    SD     34    NaN    NaN  ...         NaN   NaN      34                  100
# 43    PR    111    NaN    NaN  ...         NaN   NaN     111                  100
# 49    UT     67    NaN    NaN  ...         NaN   NaN      67                  100
# 51    VI      4    NaN    NaN  ...         NaN   NaN       4                  100
# 56    WY      7    NaN    NaN  ...         NaN   NaN       7                  100
# 37    NV    306    NaN    NaN  ...         NaN   NaN     306                  100
# 13    GU      5    NaN    NaN  ...         NaN   NaN       5                  100
# 33    NE     98    NaN    NaN  ...         NaN   NaN      98                  100
# 32    ND     35    NaN    NaN  ...         NaN   NaN      35                  100
# 4     AS    NaN    NaN    NaN  ...         NaN   NaN     NaN                  100
# 28    MP      2    NaN    NaN  ...         NaN   NaN       2                  100
# 24    ME     64    NaN    NaN  ...         NaN   NaN      64                  100
# 36    NM    200    NaN    NaN  ...         NaN   NaN     200                  100
# 14    HI     17    NaN    NaN  ...         NaN   NaN      17                  100
# 18    IN   1379    860    220  ...         NaN   158     131                   10
# 15    IA    265    210     15  ...         NaN   NaN      26                   10
# 54    WI    400    266    117  ...         NaN     2       4                    1
# 17    IL   3406   1450   1106  ...         NaN    27      27                    1
# 52    VT     53     49    NaN  ...         NaN     2       0                    0
# 9     DC    323     35    252  ...         NaN     2       0                    0
# 19    KS    157     99     47  ...         NaN     1       0                    0
# 30    MT     16     12    NaN  ...         NaN   NaN     NaN                    0
# 29    MS    430    152    203  ...         NaN     1       0                    0
# 1     AK     10    NaN    NaN  ...         NaN   NaN       0                  NaN
#
# [56 rows x 12 columns]

# %%
df.race_percent_unknown.values
# Out:
# array(['94', '9', '8', '7', '7', '66', '6', '56', '52', '5', '5', '5',
#        '46', '4', '4', '4', '35', '3', '3', '3', '3', '23', '20', '20',
#        '2', '2', '19', '18', '13', '13', '12', '11', '100', '100', '100',
#        '100', '100', '100', '100', '100', '100', '100', '100', '100',
#        '100', '100', '10', '10', '1', '1', '0', '0', '0', '0', '0', nan],
#       dtype=object)

# %%
# Looking at the data, the state with race_percent_unknown "NaN" is AK, 
# which has 10 deaths and no info under any race, 
# so update the spreadsheet with 100 percent unknown for AK. 
df['race_percent_unknown'].replace(float('nan'), 100, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
# Verify the update
df.head()
# Out:
#    state total white  black   ... multiracial other unknown race_percent_unknown
# 55    WV    50      2      1  ...         NaN   NaN      47                   94
# 53    WA   931    622     28  ...          10    19      86                    9
# 10    DE   224    132     58  ...         NaN     3      17                    8
# 21    LA  2213    833   1184  ...         NaN    16     157                    7
# 7     CO   971    619     63  ...          10     6      63                    7
#
# [5 rows x 12 columns]

# %%
df.dtypes
# Out:
# state                   object
# total                   object
# white                   object
# black                   object
# latinx_hispanic         object
# asian                   object
# aian                    object
# nhpi                    object
# multiracial             object
# other                   object
# unknown                 object
# race_percent_unknown    object
# dtype: object

# %%
df.head()
# Out:
#    state total white  black   ... multiracial other unknown race_percent_unknown
# 55    WV    50      2      1  ...         NaN   NaN      47                   94
# 53    WA   931    622     28  ...          10    19      86                    9
# 10    DE   224    132     58  ...         NaN     3      17                    8
# 21    LA  2213    833   1184  ...         NaN    16     157                    7
# 7     CO   971    619     63  ...          10     6      63                    7
#
# [5 rows x 12 columns]

# %%
df = df.set_index('state')
df.head()
# Out:
#       total white  black   ... other unknown race_percent_unknown
# state                      ...
# WV       50      2      1  ...   NaN      47                   94
# WA      931    622     28  ...    19      86                    9
# DE      224    132     58  ...     3      17                    8
# LA     2213    833   1184  ...    16     157                    7
# CO      971    619     63  ...     6      63                    7
#
# [5 rows x 11 columns]

# %%
# For visualization, drop rows that are not contiguous 50 states
df.drop(['AS', 'DC', 'GU', 'MP', 'PR', 'VI'], inplace=True)
df.shape
# Out:
# (50, 11)

# %%
df = df.apply(pd.to_numeric)

# df = df.astype({'state': str, 'total': int, 'white ': int, 'black ': int, 'latinx_hispanic': int, 'asian': int,
#        'aian': int, 'nhpi': int, 'multiracial': int, 'other': int, 'unknown': int,
#        'race_percent_unknown': int})

# %%
df.dtypes
# Out:
# total                     int64
# white                   float64
# black                   float64
# latinx_hispanic         float64
# asian                   float64
# aian                    float64
# nhpi                    float64
# multiracial             float64
# other                   float64
# unknown                 float64
# race_percent_unknown      int64
# dtype: object

# %% [markdown]
# 14 states have 100% unknown race.

# %%
# Sort by most unknown
df.sort_values('race_percent_unknown', ascending=False)
# Out:
#        total  white   black   ...  other  unknown  race_percent_unknown
# state                         ...
# AK        10     NaN     NaN  ...    NaN      0.0                   100
# SD        34     NaN     NaN  ...    NaN     34.0                   100
# HI        17     NaN     NaN  ...    NaN     17.0                   100
# NM       200     NaN     NaN  ...    NaN    200.0                   100
# ME        64     NaN     NaN  ...    NaN     64.0                   100
# ND        35     NaN     NaN  ...    NaN     35.0                   100
# NE        98     NaN     NaN  ...    NaN     98.0                   100
# NV       306     NaN     NaN  ...    NaN    306.0                   100
# WY         7     NaN     NaN  ...    NaN      7.0                   100
# UT        67     NaN     NaN  ...    NaN     67.0                   100
# WV        50     2.0     1.0  ...    NaN     47.0                    94
# TX      1088   176.0    66.0  ...    1.0    722.0                    66
# NH       133    54.0     0.0  ...    1.0     74.0                    56
# PA      3707  1357.0   388.0  ...   11.0   1911.0                    52
# MA      4979  1911.0   253.0  ...  154.0   2280.0                    46
# NY     21478  5423.0  3409.0  ...  575.0   7485.0                    35
# MN       578   387.0    34.0  ...    2.0    132.0                    23
# RI       422   269.0    20.0  ...    6.0     83.0                    20
# OR       109    81.0     5.0  ...    6.0     25.0                    20
# MO       482   197.0   159.0  ...   24.0     91.0                    19
# AZ       536   240.0    17.0  ...    7.0     95.0                    18
# SC       331   161.0   122.0  ...    3.0     42.0                    13
# VA       839   451.0   187.0  ...   92.0    109.0                    13
# KY       304   211.0    50.0  ...    NaN     36.0                    12
# NJ      9255  4354.0  1578.0  ...  438.0    993.0                    11
# IN      1379   860.0   220.0  ...  158.0    131.0                    10
# IA       265   210.0    15.0  ...    NaN     26.0                    10
# WA       931   622.0    28.0  ...   19.0     86.0                     9
# DE       224   132.0    58.0  ...    3.0     17.0                     8
# CO       971   619.0    63.0  ...    6.0     63.0                     7
# LA      2213   833.0  1184.0  ...   16.0    157.0                     7
# MD      1538   637.0   631.0  ...   22.0     88.0                     6
# NC       547   312.0   177.0  ...   20.0     30.0                     5
# MI      4570  2229.0  1865.0  ...   91.0    227.0                     5
# OH      1341  1017.0   218.0  ...   10.0     71.0                     5
# OK       272   206.0    22.0  ...    7.0     12.0                     4
# AR        82    45.0    30.0  ...    4.0      3.0                     4
# FL      1721   859.0   363.0  ...   60.0     76.0                     4
# CA      2657   891.0   264.0  ...   36.0     89.0                     3
# TN       243   146.0    76.0  ...    7.0      8.0                     3
# CT      2967  2127.0   439.0  ...   14.0     89.0                     3
# ID        67    62.0     1.0  ...    NaN      2.0                     3
# AL       393   194.0   178.0  ...    5.0      9.0                     2
# GA      1405   602.0   693.0  ...    9.0     22.0                     2
# WI       400   266.0   117.0  ...    2.0      4.0                     1
# IL      3406  1450.0  1106.0  ...   27.0     27.0                     1
# VT        53    49.0     NaN  ...    2.0      0.0                     0
# KS       157    99.0    47.0  ...    1.0      0.0                     0
# MT        16    12.0     NaN  ...    NaN      NaN                     0
# MS       430   152.0   203.0  ...    1.0      0.0                     0
#
# [50 rows x 11 columns]

# %%
# Show when unknown race > 30 %
df[df['race_percent_unknown'] > 30]
# Out:
#        total  white   black   ...  other  unknown  race_percent_unknown
# state                         ...
# WV        50     2.0     1.0  ...    NaN     47.0                    94
# TX      1088   176.0    66.0  ...    1.0    722.0                    66
# NH       133    54.0     0.0  ...    1.0     74.0                    56
# PA      3707  1357.0   388.0  ...   11.0   1911.0                    52
# MA      4979  1911.0   253.0  ...  154.0   2280.0                    46
# NY     21478  5423.0  3409.0  ...  575.0   7485.0                    35
# SD        34     NaN     NaN  ...    NaN     34.0                   100
# UT        67     NaN     NaN  ...    NaN     67.0                   100
# WY         7     NaN     NaN  ...    NaN      7.0                   100
# NV       306     NaN     NaN  ...    NaN    306.0                   100
# NE        98     NaN     NaN  ...    NaN     98.0                   100
# ND        35     NaN     NaN  ...    NaN     35.0                   100
# ME        64     NaN     NaN  ...    NaN     64.0                   100
# NM       200     NaN     NaN  ...    NaN    200.0                   100
# HI        17     NaN     NaN  ...    NaN     17.0                   100
# AK        10     NaN     NaN  ...    NaN      0.0                   100
#
# [16 rows x 11 columns]

# %%
# Drop columns not using for visualization
df.drop(['total', 'white ', 'black ', 'latinx_hispanic', 'asian', 'aian', 'nhpi',
       'multiracial', 'other', 'unknown'],axis=1, inplace=True)

# %%
# Write df to csv in gdrive via colab for map
with open('/content/drive/My Drive/Colab Notebooks/df.csv', 'w') as f:
  df.to_csv(f)

# %% [markdown]
# 21 territories have major gaps (> 30% unknown) for the racial data reported.

# %%
# JSON overlay for choropleth map
base = 'https://github.com/python-visualization/folium/raw/master/examples/data/'
antarctic_ice_edge = base + 'antarctic_ice_edge.json'

m = folium.Map(
    location=[-59.1759, -11.6016],
    tiles='Mapbox Bright',
    zoom_start=2
)

folium.GeoJson(
    antarctic_ice_edge,
    name='geojson'
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
state_geo = base + 'us-states.json'

#state_race_gaps = base + 'df_fewm2.csv' # path is '/content/drive/My Drive/Colab Notebooks/df_fewm2.csv'
state_race_gaps = '/content/drive/My Drive/Colab Notebooks/df.csv'
state_data = pd.read_csv(state_race_gaps)

m = folium.Map(location=[48, -102], zoom_start=3)

m.choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_data,
    columns=['state', 'race_percent_unknown'],
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Race Unknown Rate (%)'
)

folium.LayerControl().add_to(m)

m
# Out:
# /usr/local/lib/python3.6/dist-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
