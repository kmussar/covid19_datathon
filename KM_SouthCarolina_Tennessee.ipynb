# %% [markdown]
# # Case Study
# ### Non-Hispanic Black or African American
# * **South Carolina** - 53.5% of COVID-19 deaths; 30% of population
# * **Tennessee** - 28.2% of COVID-19 deaths; 33.2% of population

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('county_detailed_demographics_and_deaths.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3273 entries, 0 to 3272
# Columns: 360 entries, Unnamed: 0 to deaths
# dtypes: float64(348), int64(7), object(5)
# memory usage: 9.0+ MB
#    Unnamed: 0  FIPS State1       Area_Name  Rural-urban_Continuum Code_2013  \
# 0           0     0     US   United States                              NaN
# 1           1  1000     AL         Alabama                              NaN
# 2           2  1001     AL  Autauga County                              2.0
# 3           3  1003     AL  Baldwin County                              3.0
# 4           4  1005     AL  Barbour County                              6.0
#
#    Urban_Influence_Code_2013  Economic_typology_2015  POP_ESTIMATE_2018  \
# 0                        NaN                     NaN          327167434
# 1                        NaN                     NaN            4887871
# 2                        2.0                     0.0              55601
# ...

# %%
# create dataframe for TN 
tn = df[df['State Abbreviation'] == 'TN']
tn.head()
# Out:
#       Unnamed: 0   FIPS State1        Area_Name  \
# 2472        2472  47001     TN  Anderson County
# 2473        2473  47003     TN   Bedford County
# 2474        2474  47005     TN    Benton County
# 2475        2475  47007     TN   Bledsoe County
# 2476        2476  47009     TN    Blount County
#
#       Rural-urban_Continuum Code_2013  Urban_Influence_Code_2013  \
# 2472                              2.0                        2.0
# 2473                              4.0                        3.0
# 2474                              7.0                        9.0
# 2475                              8.0                        7.0
# 2476                              2.0                        2.0
#
#       Economic_typology_2015  POP_ESTIMATE_2018  N_POP_CHG_2018  Births_2018  \
# 2472                     3.0              76482           295.0        769.0
# 2473                     3.0              49038           900.0        646.0
# ...

# %% [raw]
# # save to csv to play with in Tableau
# tn.to_csv('tn.csv')

# %%
# create dataframe for SC 
sc = df[df['State Abbreviation'] == 'SC']
sc.head()
# Out:
#        FIPS State         Area_Name  Rural-urban_Continuum Code_2013  \
# 2357  45000    SC    South Carolina                              NaN
# 2358  45001    SC  Abbeville County                              6.0
# 2359  45003    SC      Aiken County                              2.0
# 2360  45005    SC  Allendale County                              6.0
# 2361  45007    SC   Anderson County                              2.0
#
#       Urban_Influence_Code_2013  Economic_typology_2015  POP_ESTIMATE_2018  \
# 2357                        NaN                     NaN            5084127
# 2358                        5.0                     3.0              24541
# 2359                        2.0                     0.0             169401
# 2360                        6.0                     3.0               8903
# 2361                        2.0                     3.0             200482
#
#       N_POP_CHG_2018  Births_2018  Deaths_2018  ...  MURDER  RAPE  ROBBERY  \
# ...

# %% [raw]
# # save to csv to play with in Tableau
# sc.to_csv('sc.csv')

# %%
sc_corr_matrix = sc.corr()
sc_corr_matrix['deaths'] = sc_corr_matrix['deaths'].abs()
sc_corr_matrix.sort_values(by='deaths', ascending=False, inplace=True)
sc_corr_matrix.reset_index(inplace=True)
sc_corr_matrix[['index','deaths']]
# Out:
#                                                  index        deaths
# 0                                               deaths  1.000000e+00
# 1                                                cases  8.996590e-01
# 2                                           HBA_FEMALE  8.391486e-01
# 3                                          HBAC_FEMALE  8.384293e-01
# 4    Total number of UCR (Uniform Crime Report) Ind...  8.355806e-01
# 5                                              BURGLRY  8.343197e-01
# 6                                             HBA_MALE  8.315194e-01
# 7                        Number of AGGRAVATED ASSAULTS  8.291512e-01
# 8                                            HBAC_MALE  8.287375e-01
# 9    DISABILITY STATUS OF THE CIVILIAN NONINSTITUTI...  8.216721e-01
# 10                                             ROBBERY  8.213973e-01
# 11   Total number of UCR (Uniform Crime Report) ind...  8.199137e-01
# 12                                MOTOR VEHICLE THEFTS  8.145603e-01
# ...

# %%
tn_corr_matrix = tn.corr()
tn_corr_matrix['deaths'] = tn_corr_matrix['deaths'].abs()
tn_corr_matrix.sort_values(by='deaths', ascending=False, inplace=True)
tn_corr_matrix.reset_index(inplace=True)
tn_corr_matrix[['index','deaths']]
# Out:
#                                                  index        deaths
# 0                                               deaths  1.000000e+00
# 1                                      Female_age0to17  8.497728e-01
# 2                                       Total_age0to17  8.493634e-01
# 3                                        Male_age0to17  8.489421e-01
# 4                                      Unemployed_2018  8.484386e-01
# 5                                                cases  8.478065e-01
# 6                                 HOUSEHOLDS BY TYPE!!  8.467038e-01
# 7            COUNTY POPULATION-AGENCIES REPORT ARRESTS  8.441591e-01
# 8                                          Births_2018  8.426062e-01
# 9             COUNTY POPULATION-AGENCIES REPORT CRIMES  8.418453e-01
# 10          Some college or associate's degree 2014-18  8.409763e-01
# 11                                          TOT_FEMALE  8.389157e-01
# 12                                        Total_Female  8.389157e-01
# ...
